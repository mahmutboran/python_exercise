# %% [markdown]
# Python Exercise 9: Given two strings, s1 and s2. Write a program to create a new string s3 by appending s2 in the middle of s1.

# %% [markdown]
# ![Screen Shot 2021-10-19 at 1.43.03 PM.png](data:image/png;base64,...)
